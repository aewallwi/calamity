# %% [markdown]
# <a href="https://colab.research.google.com/github/aewallwi/calamity/blob/main/examples/Calamity_Sparse_Mode_Example_Garray_15_Elements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sun Aug  1 00:57:20 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install git+https://github.com/aewallwi/calamity.git
# Out:
# Collecting git+https://github.com/aewallwi/calamity.git
#   Cloning https://github.com/aewallwi/calamity.git to /tmp/pip-req-build-2ex0_x5_
#   Running command git clone -q https://github.com/aewallwi/calamity.git /tmp/pip-req-build-2ex0_x5_
# Collecting uvtools@ git+git://github.com/HERA-Team/uvtools
#   Cloning git://github.com/HERA-Team/uvtools to /tmp/pip-install-n4b4v4wt/uvtools_3ccdc2fdd90f42b796eae6224e7ef8c9
#   Running command git clone -q git://github.com/HERA-Team/uvtools /tmp/pip-install-n4b4v4wt/uvtools_3ccdc2fdd90f42b796eae6224e7ef8c9
# Collecting pyuvdata
#   Downloading pyuvdata-2.2.1.tar.gz (62.3 MB)
#      |████████████████████████████████| 62.3 MB 3.0 kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from calamity==0.0.1) (1.19.5)
# Requirement already satisfied: tensorflow>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from calamity==0.0.1) (2.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from calamity==0.0.1) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from calamity==0.0.1) (4.41.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from uvtools@ git+git://github.com/HERA-Team/uvtools->calamity==0.0.1) (1.15.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (3.7.4.3)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (1.6.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (3.3.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (1.1.2)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (2.5.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (1.12.1)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (2.5.0)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (1.34.1)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (3.1.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (0.36.2)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (0.2.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (0.4.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (1.12)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (0.12.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (3.17.3)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (2.5.0.dev2021032900)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.0->calamity==0.0.1) (1.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow>=2.5.0->calamity==0.0.1) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (0.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (2.23.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (1.32.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (1.8.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (57.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (3.3.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (4.6.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.5.0->calamity==0.0.1) (3.5.0)
# Requirement already satisfied: astropy>=4.2.1 in /usr/local/lib/python3.7/dist-packages (from pyuvdata->calamity==0.0.1) (4.2.1)
# Collecting setuptools-scm
#   Using cached setuptools_scm-6.0.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: pyerfa in /usr/local/lib/python3.7/dist-packages (from astropy>=4.2.1->pyuvdata->calamity==0.0.1) (2.0.0)
# Building wheels for collected packages: calamity, uvtools, pyuvdata
#   Building wheel for calamity (setup.py) ... done
#   Created wheel for calamity: filename=calamity-0.0.1-py3-none-any.whl size=725974 sha256=6a1ff780c6487693ad3f59c53ca314c6f27aebd39a76b33a3074c9974c42ed45
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j7fuo45o/wheels/14/57/67/7666166d65813cf0478a60e75899a5e5b68b26b160c0ef8112
#   Building wheel for uvtools (setup.py) ... done
#   Created wheel for uvtools: filename=uvtools-0.1.0-py3-none-any.whl size=1602355 sha256=b571f3d15d7d994058d90f07f25b8c2a76d93ea173d3898cd9351455e80464d7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j7fuo45o/wheels/fd/83/d4/bafce1b1f0c6d584ca7a661d35341ad0ef17652b4f2c8b2ae6
#   Building wheel for pyuvdata (PEP 517) ... done
#   Created wheel for pyuvdata: filename=pyuvdata-2.2.1-cp37-cp37m-linux_x86_64.whl size=64364204 sha256=3458c0d3cf85f8db4654532e1702ae89fd53a3e304476c292c5ec32c7d4c8ec2
#   Stored in directory: /root/.cache/pip/wheels/e6/02/cc/5f1d611ff5505b43286624bf1d349a8a9d9a4268e613c0dd35
# Successfully built calamity uvtools pyuvdata
# Installing collected packages: setuptools-scm, uvtools, pyuvdata, calamity
# Successfully installed calamity-0.0.1 pyuvdata-2.2.1 setuptools-scm-6.0.1 uvtools-0.1.0

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from calamity import cal_utils
from calamity import calamity
import numpy as np
from uvtools import dspec
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import copy
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def delay_transform_sort_by_baseline_length(uvd, tind=0, polind=0, window='bh', min_bl=0.1, fold=True):
    """
    generate an (NF x NBL) array with baselines arranged in ascending length

    Parameters
    ----------
    uvd: UVData object
        UVData with data that you want to inspect FFT of.
    polind: int, optional
        index of polarization to return.
        default is 0.
    window: str, optional
        fourier transform window function.
        default is blackman harris.
    min_bl: float, optional
        minimum baseline length to include
        default is 0.1 (meters)

    Returns
    -------
    bl_lens: array-like
        Nbls float array with lengths of each baseline.
    delays: array-like
        Nfreqs float array of delays for each baseline.
    fftd_data: array-like
        Nbls x Nfreqs array of data that has been Fourier transformed along the
        frequency axis. Baselines are arranged along baseline axis in ascending length.
    """
    data_inds = np.where(uvd.time_array == np.unique(uvd.time_array)[tind])[0]
    data = uvd.data_array[data_inds, 0, :, polind].reshape(len(data_inds), uvd.Nfreqs)
    bl_lens = np.linalg.norm(uvd.uvw_array[data_inds], axis=1)
    sorted_lens = np.argsort(bl_lens)
    data = data[sorted_lens, :]
    bl_lens = bl_lens[sorted_lens]
    data = data[bl_lens > min_bl]
    bl_lens = bl_lens[bl_lens > min_bl]
    wf = dspec.gen_window(window, uvd.Nfreqs)
    delays = 1e9 * np.fft.fftshift(np.fft.fftfreq(uvd.Nfreqs, np.mean(np.diff(uvd.freq_array))))
    fftd_data =  np.fft.fftshift(np.fft.fft(np.fft.fftshift(wf[None, :] * data, axes=1), axis=1), axes=1)
    if fold:
      fftd_data = .5 * (fftd_data[:, uvd.Nfreqs//2:] + fftd_data[:, :uvd.Nfreqs//2][:, ::-1])
      delays = delays[uvd.Nfreqs//2:]
    return bl_lens, delays, fftd_data

# %%
from calamity.data import DATA_PATH
import glob
import os
from pyuvdata import UVData
uvd_fg = UVData()
uvd_fg.read_uvh5(glob.glob(os.path.join(DATA_PATH, '*nant15*gleam*.uvh5'))[0])
uvd_eor = UVData()
uvd_eor.read_uvh5(glob.glob(os.path.join(DATA_PATH, '*nant15*eor*.uvh5'))[0])
uvd_eor.data_array *= 1
uvd_total = copy.deepcopy(uvd_eor)
uvd_total.data_array += uvd_fg.data_array

# %%
# generate uncalibrated data.
uvd_uncalib = copy.deepcopy(uvd_total)
# generate gains
gains = cal_utils.blank_uvcal_from_uvdata(uvd_uncalib)
gains.gain_array = gains.gain_array + 1e-1 * np.random.randn(*gains.gain_array.shape) + 1e-1j * np.random.randn(*gains.gain_array.shape)
# apply gains
uvd_uncalib = cal_utils.apply_gains(uvd_uncalib, gains, inverse=True)

# %%
fig, axarr = plt.subplots(1, 3)
fig.set_size_inches(18, 6)
for uvdt, ax, label in zip([uvd_eor, uvd_fg, uvd_total, uvd_uncalib], axarr, ['EoR',  'Foregrounds', 'Foregrounds + EoR', 'Corrupted Foregrounds + EoR']):
  bl, dly, wedge = delay_transform_sort_by_baseline_length(uvdt)
  blg, dlyg = np.meshgrid(bl, dly)
  plt.sca(ax)
  plt.pcolor(blg, dlyg, np.abs(wedge).T, norm=LogNorm(1e-1, np.abs(uvd_total.data_array).max()), cmap='inferno')
  plt.title(label)
  plt.ylim(0, 2000)
  plt.colorbar()

# %%
blinds = [10, 30, 100]
fig, axarr = plt.subplots(1, len(blinds))
fig.set_size_inches(24, 8)
labels = ['True FG + EoR', 'True EoR']
for blnum, blind in enumerate(blinds):
    plt.sca(axarr[blnum])
    for i, uvt in enumerate([uvd_total,  uvd_eor]):
        x, y, ctot = delay_transform_sort_by_baseline_length(uvt, window='bh7')
        plt.plot(y, np.abs(ctot[blind]), label=labels[i])
        plt.xlim(0, 2000)
        plt.ylim(1e-3, 1e5)
        plt.yscale('log')
    plt.title('%.1f m EW'%x[blind])
    if blnum == 0:
      plt.legend()

# %%
gains_0 = cal_utils.blank_uvcal_from_uvdata(uvd_uncalib)
model_fit, resid_fit, gains_fit, fitting_info = calamity.calibrate_and_model_dpss(min_dly=2./.3, offset=2./.3, 
                                                                                uvdata=uvd_uncalib, sky_model=uvd_uncalib, freeze_model=False, 
                                                                                gains=gains_0, notebook_progressbar=True, correct_resid=True, correct_model=True,
                                                                                learning_rate=1e-2, verbose=True,
                                                                                use_redundancy=False)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=105.0), HTML(value='')))
# 2021-08-01 00:59:04.715076 Computing foreground components matrices...
#
# 2021-08-01 00:59:04.748660Finished Converting Foreground Modeling Components to Tensors...
#
# 2021-08-01 00:59:04.748822 Working on pol xx, 1 of 1...
#
# 2021-08-01 00:59:04.750159 Working on time 1 of 1...
#
# 2021-08-01 00:59:04.750236 Tensorizing data...
#
# 2021-08-01 00:59:04.782427 Tensorizing Gains...
#
# 2021-08-01 00:59:04.783121 Tensorizing Foreground coeffs...
#
# 2021-08-01 00:59:04.783183 Computing initial foreground coefficient guesses using linear-leastsq...
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 2021-08-01 00:59:05.110833 Finished initial foreground coefficient guesses...
#
# 2021-08-01 00:59:05.110897 Computing initial foreground coefficient guesses using linear-leastsq...
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# 2021-08-01 00:59:05.457456 Finished initial foreground coefficient guesses...
#
# 2021-08-01 00:59:05.476608 Performing gradient descent on 3000 complex gain parameters...
# Performing gradient descent on total of 13965 complex foreground parameters
# Foreground Parameters grouped into chunks of shape ((nvecs, ngrps): nbls) ['(133, 105):1']
# 2021-08-01 00:59:05.477687 Building Computational Graph...
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 2021-08-01 00:59:06.534559 Performing Gradient Descent. Initial MSE of 3.50e-02...
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# 2021-08-01 00:59:47.010566 Finished Gradient Descent. MSE of 7.62e-08...

# %%
plt.plot(np.abs(fitting_info[0][0]['loss']))
plt.yscale('log')

# %%
fig, axarr = plt.subplots(1, 4)
fig.set_size_inches(18, 6)
for uvdt, ax, label in zip([uvd_eor, uvd_total, uvd_uncalib, resid_fit], axarr, ['EoR', 'Foregrounds + EoR', 'Gain Corrupted', 'Residual ']):
  bl, dly, wedge = delay_transform_sort_by_baseline_length(uvdt)
  blg, dlyg = np.meshgrid(bl, dly)
  plt.sca(ax)
  plt.pcolor(blg, dlyg, np.abs(wedge).T, norm=LogNorm(1e-1, 1e4), cmap='inferno')
  plt.title(label)
  plt.ylim(0, 2000)
  plt.colorbar()

# %%
blinds = [6, 10, 30, 50]
fig, axarr = plt.subplots(1, len(blinds))
fig.set_size_inches(24, 8)
for blnum, blind in enumerate(blinds):
    plt.sca(axarr[blnum])
    
    for i, uvt, label in zip(range(3), [uvd_total, uvd_eor, resid_fit], ['total', 'EoR', 'Resid']):
        x, y, ctot = delay_transform_sort_by_baseline_length(uvt, window='cs11')
        plt.plot(y, np.abs(ctot[blind]), label=label)
        plt.xlim(0, 2000)
        plt.ylim(1e-3, 1e6)
        plt.yscale('log')
    plt.title('%.1f m EW'%x[blind])
    plt.legend()
