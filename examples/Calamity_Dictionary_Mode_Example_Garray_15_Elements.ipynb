# %% [markdown]
# <a href="https://colab.research.google.com/github/aewallwi/calamity/blob/main/examples/Calamity_Dictionary_Mode_Example_Garray_15_Elements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Select the Runtime > "Change runtime type" menu to enable a GPU accelerator,
# and then re-execute this cell.

# %%
# !pip install git+https://github.com/aewallwi/calamity.git
# Out:
# Collecting git+https://github.com/aewallwi/calamity.git
#   Cloning https://github.com/aewallwi/calamity.git to /tmp/pip-req-build-v2ho46np
#   Running command git clone -q https://github.com/aewallwi/calamity.git /tmp/pip-req-build-v2ho46np
# Collecting pyuvdata
#   Downloading https://files.pythonhosted.org/packages/6c/ff/e7408bb16dc218152d2321718c3830a77cf034adfedbcb29562654e388dd/pyuvdata-2.1.5.tar.gz (62.2MB)
#      |████████████████████████████████| 62.2MB 98kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from calamity==0.0.1) (1.19.5)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from calamity==0.0.1) (2.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from calamity==0.0.1) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from calamity==0.0.1) (4.41.1)
# Collecting uvtools@ git+git://github.com/HERA-Team/uvtools
#   Cloning git://github.com/HERA-Team/uvtools to /tmp/pip-install-1infywmu/uvtools
#   Running command git clone -q git://github.com/HERA-Team/uvtools /tmp/pip-install-1infywmu/uvtools
# Collecting setuptools-scm
#   Using cached https://files.pythonhosted.org/packages/c4/d5/e50358c82026f44cd8810c8165002746cd3f8b78865f6bcf5d7f0fe4f652/setuptools_scm-6.0.1-py3-none-any.whl
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from pyuvdata->calamity==0.0.1) (3.1.0)
# Requirement already satisfied: astropy>=3.2.3 in /usr/local/lib/python3.7/dist-packages (from pyuvdata->calamity==0.0.1) (4.2.1)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (2.5.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (1.1.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (3.7.4.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (3.3.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (1.12.1)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (0.4.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (3.12.4)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (1.34.1)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (0.12.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (1.1.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (1.6.3)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (1.15.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (1.12)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (2.5.0.dev2021032900)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (2.5.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow->calamity==0.0.1) (0.36.2)
# Requirement already satisfied: setuptools>=45 in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->pyuvdata->calamity==0.0.1) (57.0.0)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py->pyuvdata->calamity==0.0.1) (1.5.2)
# Requirement already satisfied: pyerfa in /usr/local/lib/python3.7/dist-packages (from astropy>=3.2.3->pyuvdata->calamity==0.0.1) (2.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->calamity==0.0.1) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->calamity==0.0.1) (0.4.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->calamity==0.0.1) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->calamity==0.0.1) (1.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->calamity==0.0.1) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->calamity==0.0.1) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->calamity==0.0.1) (1.8.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->calamity==0.0.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->calamity==0.0.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->calamity==0.0.1) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->calamity==0.0.1) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->calamity==0.0.1) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->calamity==0.0.1) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->calamity==0.0.1) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->calamity==0.0.1) (4.2.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow->calamity==0.0.1) (4.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->calamity==0.0.1) (3.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->calamity==0.0.1) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.5->tensorflow->calamity==0.0.1) (3.4.1)
# Building wheels for collected packages: pyuvdata
#   Building wheel for pyuvdata (PEP 517) ... done
#   Created wheel for pyuvdata: filename=pyuvdata-2.1.5-cp37-cp37m-linux_x86_64.whl size=64262273 sha256=5a822f058b0c758264f3ffa7fe9fc8614593cc57ce51f68d37d83308de3ac16c
#   Stored in directory: /root/.cache/pip/wheels/62/9a/ce/49ed7a19d79b1ab2840509f77a9c85fae95be6f7de83e36dc7
# Successfully built pyuvdata
# Building wheels for collected packages: calamity, uvtools
#   Building wheel for calamity (setup.py) ... done
#   Created wheel for calamity: filename=calamity-0.0.1-cp37-none-any.whl size=619112 sha256=9fa67ef85a20e360f5f8f08be8faef8673b2a14d0920ba6cd70be651e91bca5f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gp1l2e10/wheels/ea/ec/fd/e922a360441bb5664d49470c416faac66fdb0a009ee5cb1045
#   Building wheel for uvtools (setup.py) ... done
#   Created wheel for uvtools: filename=uvtools-0.1.0-cp37-none-any.whl size=1602357 sha256=9d5afecd3df19c0375027bde9f761bf378e3839e37362770b43db68bee794da2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gp1l2e10/wheels/2c/68/61/a50df6cda18fcbd8b37075457012605effcd992118d3577eaf
# Successfully built calamity uvtools
# Installing collected packages: setuptools-scm, pyuvdata, uvtools, calamity
# Successfully installed calamity-0.0.1 pyuvdata-2.1.5 setuptools-scm-6.0.1 uvtools-0.1.0

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from calamity import utils
from calamity import calamity
import numpy as np
from uvtools import dspec
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import copy
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def delay_transform_sort_by_baseline_length(uvd, tind=0, polind=0, window='bh', min_bl=0.1, fold=True):
    """
    generate an (NF x NBL) array with baselines arranged in ascending length

    Parameters
    ----------
    uvd: UVData object
        UVData with data that you want to inspect FFT of.
    polind: int, optional
        index of polarization to return.
        default is 0.
    window: str, optional
        fourier transform window function.
        default is blackman harris.
    min_bl: float, optional
        minimum baseline length to include
        default is 0.1 (meters)

    Returns
    -------
    bl_lens: array-like
        Nbls float array with lengths of each baseline.
    delays: array-like
        Nfreqs float array of delays for each baseline.
    fftd_data: array-like
        Nbls x Nfreqs array of data that has been Fourier transformed along the
        frequency axis. Baselines are arranged along baseline axis in ascending length.
    """
    data_inds = np.where(uvd.time_array == np.unique(uvd.time_array)[tind])[0]
    data = uvd.data_array[data_inds, 0, :, polind].reshape(len(data_inds), uvd.Nfreqs)
    bl_lens = np.linalg.norm(uvd.uvw_array[data_inds], axis=1)
    sorted_lens = np.argsort(bl_lens)
    data = data[sorted_lens, :]
    bl_lens = bl_lens[sorted_lens]
    data = data[bl_lens > min_bl]
    bl_lens = bl_lens[bl_lens > min_bl]
    wf = dspec.gen_window(window, uvd.Nfreqs)
    delays = 1e9 * np.fft.fftshift(np.fft.fftfreq(uvd.Nfreqs, np.mean(np.diff(uvd.freq_array))))
    fftd_data =  np.fft.fftshift(np.fft.fft(np.fft.fftshift(wf[None, :] * data, axes=1), axis=1), axes=1)
    if fold:
      fftd_data = .5 * (fftd_data[:, uvd.Nfreqs//2:] + fftd_data[:, :uvd.Nfreqs//2][:, ::-1])
      delays = delays[uvd.Nfreqs//2:]
    return bl_lens, delays, fftd_data

# %%
from calamity.data import DATA_PATH
import glob
import os
from pyuvdata import UVData
uvd_fg = UVData()
uvd_fg.read_uvh5(glob.glob(os.path.join(DATA_PATH, '*nant15*gleam*.uvh5'))[0])
uvd_eor = UVData()
uvd_eor.read_uvh5(glob.glob(os.path.join(DATA_PATH, '*nant15*eor*.uvh5'))[0])
uvd_eor.data_array *= 1
uvd_total = copy.deepcopy(uvd_eor)
uvd_total.data_array += uvd_fg.data_array

# %%
# generate uncalibrated data.
uvd_uncalib = copy.deepcopy(uvd_total)
# generate gains
gains = utils.blank_uvcal_from_uvdata(uvd_uncalib)
gains.gain_array = gains.gain_array + 1e-1 * np.random.randn(*gains.gain_array.shape) + 1e-1j * np.random.randn(*gains.gain_array.shape)
# apply gains
uvd_uncalib = utils.apply_gains(uvd_uncalib, gains, inverse=True)

# %%
fig, axarr = plt.subplots(1, 3)
fig.set_size_inches(18, 6)
for uvdt, ax, label in zip([uvd_eor, uvd_fg, uvd_total, uvd_uncalib], axarr, ['EoR',  'Foregrounds', 'Foregrounds + EoR', 'Corrupted Foregrounds + EoR']):
  bl, dly, wedge = delay_transform_sort_by_baseline_length(uvdt)
  blg, dlyg = np.meshgrid(bl, dly)
  plt.sca(ax)
  plt.pcolor(blg, dlyg, np.abs(wedge).T, norm=LogNorm(1e-1, np.abs(uvd_total.data_array).max()), cmap='inferno')
  plt.title(label)
  plt.ylim(0, 2000)
  plt.colorbar()

# %%
blinds = [10, 30, 100]
fig, axarr = plt.subplots(1, len(blinds))
fig.set_size_inches(24, 8)
labels = ['True FG + EoR', 'True EoR']
for blnum, blind in enumerate(blinds):
    plt.sca(axarr[blnum])
    for i, uvt in enumerate([uvd_total,  uvd_eor]):
        x, y, ctot = delay_transform_sort_by_baseline_length(uvt, window='bh7')
        plt.plot(y, np.abs(ctot[blind]), label=labels[i])
        plt.xlim(0, 2000)
        plt.ylim(1e-3, 1e5)
        plt.yscale('log')
    plt.title('%.1f m EW'%x[blind])
    if blnum == 0:
      plt.legend()

# %%
gains_0 = utils.blank_uvcal_from_uvdata(uvd_uncalib)
model_fit, resid_fit, gains_fit, fitting_info = calamity.calibrate_and_model_dpss(min_dly=2./.3, offset=2./.3, 
                                                                                  uvdata=uvd_uncalib, sky_model=uvd_uncalib, freeze_model=False, 
                                                                                  gains=gains_0, notebook_progressbar=True,
                                                                                  learning_rate=1e-2, verbose=True, correct_resid=True, 
                                                                                  correct_model=True,
                                                                                  use_redundancy=False, record_var_history=True)
# Out:
# 2021-06-17 00:01:38.411782 Generating map between antenna pairs and modeling vectors...
#
# 2021-06-17 00:01:38.420345 Working on pol xx, 1 of 1...
#
# 2021-06-17 00:01:38.421913 Working on time 1 of 1...
#
# 2021-06-17 00:01:38.422036 Tensorizing Data...
#
# 2021-06-17 00:01:38.499756 Tensorizing Gains...
#
# 2021-06-17 00:01:38.500195 Tensorizing Foreground coeffs...
#
# 2021-06-17 00:01:38.569932 Building Computational Graph...
#
# 2021-06-17 00:01:53.846943 Performing Gradient Descent. Initial MSE of 3.46e-02...
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# 2021-06-17 00:22:00.078675 Finished Gradient Descent. MSE of 6.18e-08...

# %%
plt.plot(np.abs(fitting_info[0][0]['loss']))
plt.yscale('log')

# %%
fig, axarr = plt.subplots(1, 4)
fig.set_size_inches(18, 6)
for uvdt, ax, label in zip([uvd_eor, uvd_total, uvd_uncalib, resid_fit], axarr, ['EoR', 'Foregrounds + EoR', 'Gain Corrupted', 'Residual ']):
  bl, dly, wedge = delay_transform_sort_by_baseline_length(uvdt)
  blg, dlyg = np.meshgrid(bl, dly)
  plt.sca(ax)
  plt.pcolor(blg, dlyg, np.abs(wedge).T, norm=LogNorm(1e-1, 1e4), cmap='inferno')
  plt.title(label)
  plt.ylim(0, 2000)
  plt.colorbar()

# %%
blinds = [6, 10, 30, 50]
fig, axarr = plt.subplots(1, len(blinds))
fig.set_size_inches(24, 8)
for blnum, blind in enumerate(blinds):
    plt.sca(axarr[blnum])
    
    for i, uvt, label in zip(range(3), [uvd_total, uvd_eor, resid_fit], ['total', 'EoR', 'Resid']):
        x, y, ctot = delay_transform_sort_by_baseline_length(uvt, window='cs11')
        plt.plot(y, np.abs(ctot[blind]), label=label)
        plt.xlim(0, 2000)
        plt.ylim(1e-3, 1e6)
        plt.yscale('log')
    plt.title('%.1f m EW'%x[blind])
    plt.legend()
